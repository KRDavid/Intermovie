# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Import des différentes librairies

# %%
import pandas as pd
import numpy as np 
import matplotlib

# %% [markdown]
# ### Création des DataFrame à partir des fichiers TSV

# %%
df_people = pd.read_table("../data/name.basics.tsv", sep='\t')

# %%
df_films = pd.read_table("../data/title.principals.tsv", sep='\t')

# %%
df_titre = pd.read_table("../data/title.basics.tsv", sep='\t')
# Out:
# C:\Users\utilisateur\anaconda3\envs\p5 films\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df_note = pd.read_table("../data/title.ratings.tsv", sep='\t')

# %% [markdown]
# ## 1. DATAFRAME PEOPLE

# %%
df_people.head()    # Affiche le début du Dataframe
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0050419,tt0053137,tt0072308,tt0043044
# 1              actress,soundtrack  tt0071877,tt0117057,tt0038355,tt0037382
# 2     actress,soundtrack,producer  tt0054452,tt0049189,tt0059956,tt0057345
# 3         actor,writer,soundtrack  tt0077975,tt0072562,tt0080455,tt0078723
# 4           writer,director,actor  tt0069467,tt0050976,tt0083922,tt0050986

# %%
df_people.shape    # Retourne le nombre de lignes, et de colonnes
# Out:
# (9706922, 6)

# %%
list(df_people)   # Retourne le nom des colonnes
# Out:
# ['nconst',
#  'primaryName',
#  'birthYear',
#  'deathYear',
#  'primaryProfession',
#  'knownForTitles']

# %%
df_people_clean = df_people.dropna()    # Supprime les lignes vides

# %%
df_people_clean.shape
# Out:
# (7775897, 6)

# %%
df_people_clean.head()
# Out:
#        primaryName               primaryProfession  \
# 0     Fred Astaire  soundtrack,actor,miscellaneous
# 1    Lauren Bacall              actress,soundtrack
# 2  Brigitte Bardot     actress,soundtrack,producer
# 3     John Belushi         actor,writer,soundtrack
# 4   Ingmar Bergman           writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0053137,tt0072308,tt0043044
# 1  tt0071877,tt0117057,tt0038355,tt0037382
# 2  tt0054452,tt0049189,tt0059956,tt0057345
# 3  tt0077975,tt0072562,tt0080455,tt0078723
# 4  tt0069467,tt0050976,tt0083922,tt0050986

# %%
df_people_clean = df_people_clean.drop(["nconst", "birthYear","deathYear"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1da35005e23d> in <module>
# ----> 1 df_people_clean = df_people_clean.drop(["nconst", "birthYear","deathYear"], axis = 1)
#
# ~\anaconda3\envs\p5 films\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~\anaconda3\envs\p5 films\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
df_people_clean
# Out:
#                 primaryName                    primaryProfession  \
# 0              Fred Astaire       soundtrack,actor,miscellaneous
# 1             Lauren Bacall                   actress,soundtrack
# 2           Brigitte Bardot          actress,soundtrack,producer
# 3              John Belushi              actor,writer,soundtrack
# 4            Ingmar Bergman                writer,director,actor
# ...                     ...                                  ...
# 9706912           Lu Bevins                             director
# 9706916       Sambit Mishra                               writer
# 9706917   Romeo del Rosario  animation_department,art_department
# 9706919  Harikrishnan Rajan                      cinematographer
# 9706920         Aayush Nair                      cinematographer
#
#                                   knownForTitles
# 0        tt0050419,tt0053137,tt0072308,tt0043044
# 1        tt0071877,tt0117057,tt0038355,tt0037382
# ...

# %%
a = df_people_clean["primaryName"][40]   # Renvois la 40ème ligne de la colonne primaryName

# %%
a
# Out:
# 'Akira Kurosawa'

# %%
df_acteur = df_people_clean[["primaryName","primaryProfession","knownForTitles"]][df_people_clean["primaryProfession"].str.contains("actor|actress", regex=True)]

# %%
df_acteur
# Out:
#               primaryName               primaryProfession  \
# 0            Fred Astaire  soundtrack,actor,miscellaneous
# 1           Lauren Bacall              actress,soundtrack
# 2         Brigitte Bardot     actress,soundtrack,producer
# 3            John Belushi         actor,writer,soundtrack
# 4          Ingmar Bergman           writer,director,actor
# ...                   ...                             ...
# 9706900    Zakariya Ganim                           actor
# 9706901         Sebi John                           actor
# 9706902        Dani Jacob                           actor
# 9706903        Sexy Angel                         actress
# 9706904  Sanjai Kuriakose                           actor
#
#                                   knownForTitles
# 0        tt0050419,tt0053137,tt0072308,tt0043044
# 1        tt0071877,tt0117057,tt0038355,tt0037382
# 2        tt0054452,tt0049189,tt0059956,tt0057345
# 3        tt0077975,tt0072562,tt0080455,tt0078723
# ...

# %%
df_titre
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6321297  tt9916848  tvEpisode              Episode #3.17
# 6321298  tt9916850  tvEpisode              Episode #3.19
# 6321299  tt9916852  tvEpisode              Episode #3.20
# 6321300  tt9916856      short                   The Wind
# 6321301  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894      \N              1
# 1           Le clown et ses chiens        0      1892      \N              5
# ...

# %%
df_titre_clean = df_titre.dropna()

# %%
df_titre_clean = df_people_clean.drop(["titleType", "originalTitle","isAdult","startYear","endYear","runtimeMinutes","genres"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-8500d1aa602c> in <module>
# ----> 1 df_titre_clean = df_people_clean.drop(["titleType", "originalTitle","isAdult","startYear","endYear","runtimeMinutes","genres"], axis = 1)
#
# ~\anaconda3\envs\p5 films\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~\anaconda3\envs\p5 films\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
df_titre_clean
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6321297  tt9916848  tvEpisode              Episode #3.17
# 6321298  tt9916850  tvEpisode              Episode #3.19
# 6321299  tt9916852  tvEpisode              Episode #3.20
# 6321300  tt9916856      short                   The Wind
# 6321301  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894      \N              1
# 1           Le clown et ses chiens        0      1892      \N              5
# ...
